# %% [markdown]
# ```python
# The os module in python provides a way to interact with the operating system. It includes functionalities for file and directory manipulation, environment variables, process management, and more.
# ```

# %%
import os #built-in library

print(dir(os))  #all of the attributes and methods that we have access to.
# Out:
# ['DirEntry', 'EX_OK', 'F_OK', 'GenericAlias', 'Mapping', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_AddedDllDirectory', '_Environ', '__all__', '__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_walk_symlinks_as_files', '_wrap_close', 'abc', 'abort', 'access', 'add_dll_directory', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsy
# ...

# %%
print(os.getcwd())  #gets current working directory
# Out:
# c:\Users\vamsh\OneDrive\Desktop\Python Concepts (A to Z)\Python-Concepts-A-to-Z-by-CoreySchefer\18_os_module

# %%
os.chdir('c:/Users/vamsh/OneDrive/Desktop/')  #To change directory

# %%
print(os.getcwd())
# Out:
# c:\Users\vamsh\OneDrive\Desktop

# %%
print(os.listdir())  #files and folders on desktop
# Out:
# ['.git', '.hgf.txt', 'APPLICATION SYSTEM TRACKING', 'ATS', 'Audio', 'ayncio1', 'Blitz.lnk', 'books to read', 'cataract detection', 'Cataract-Detection-and-Classification', 'certificates', 'cfx_dashboard', 'Data', 'Datascience-projects', 'Deepgram', 'desktop.ini', 'Discord.lnk', 'Django', 'django and postgre', 'django blog app', 'django blog project', 'django channels', 'django models', 'django rest framework', 'django-api-error-handling', 'django-celery', 'django-concepts', 'django-project', 'django-user-model', 'Django2', 'Docker Desktop.lnk', 'DSA PYTHON', 'fav chikk', 'FILE.sql', 'final project', 'final project.zip', 'Flask project 1', 'for testing', 'Front-End', 'HTML', 'kaggle projects', 'MACHINE LEARNING', 'Microsoft Teams classic (work or school).lnk', 'mid term Project presentaion.pptx', 'ML project', 'mongodb', 'MongoDBCompass.lnk', 'Movie Recomendation System', 'mysql', 'Natural Language Processing', 'New folder', 'OpenAI', 'pgAdmin 4.lnk', 'Porfolio-HTML', 'portfolio-HTML&
# ...

# %%
os.mkdir('os-demo-2')  #creates a single directory at the specified path.

# %%
print(os.listdir())
# Out:
# ['.git', '.hgf.txt', 'APPLICATION SYSTEM TRACKING', 'ATS', 'Audio', 'ayncio1', 'Blitz.lnk', 'books to read', 'cataract detection', 'Cataract-Detection-and-Classification', 'certificates', 'cfx_dashboard', 'Data', 'Datascience-projects', 'Deepgram', 'desktop.ini', 'Discord.lnk', 'Django', 'django and postgre', 'django blog app', 'django blog project', 'django channels', 'django models', 'django rest framework', 'django-api-error-handling', 'django-celery', 'django-concepts', 'django-project', 'django-user-model', 'Django2', 'Docker Desktop.lnk', 'DSA PYTHON', 'fav chikk', 'FILE.sql', 'final project', 'final project.zip', 'Flask project 1', 'for testing', 'Front-End', 'HTML', 'kaggle projects', 'MACHINE LEARNING', 'Microsoft Teams classic (work or school).lnk', 'mid term Project presentaion.pptx', 'ML project', 'mongodb', 'MongoDBCompass.lnk', 'Movie Recomendation System', 'mysql', 'Natural Language Processing', 'New folder', 'OpenAI', 'os-demo-2', 'pgAdmin 4.lnk', 'Porfolio-HTML', 'po
# ...

# %%
os.makedirs('nested_dir/inner_dir') #creates subdirectories in a directory

# %%
print(os.listdir())
# Out:
# ['.git', '.hgf.txt', 'APPLICATION SYSTEM TRACKING', 'ATS', 'Audio', 'ayncio1', 'Blitz.lnk', 'books to read', 'cataract detection', 'Cataract-Detection-and-Classification', 'certificates', 'cfx_dashboard', 'Data', 'Datascience-projects', 'Deepgram', 'desktop.ini', 'Discord.lnk', 'Django', 'django and postgre', 'django blog app', 'django blog project', 'django channels', 'django models', 'django rest framework', 'django-api-error-handling', 'django-celery', 'django-concepts', 'django-project', 'django-user-model', 'Django2', 'Docker Desktop.lnk', 'DSA PYTHON', 'fav chikk', 'FILE.sql', 'final project', 'final project.zip', 'Flask project 1', 'for testing', 'Front-End', 'HTML', 'kaggle projects', 'MACHINE LEARNING', 'Microsoft Teams classic (work or school).lnk', 'mid term Project presentaion.pptx', 'ML project', 'mongodb', 'MongoDBCompass.lnk', 'Movie Recomendation System', 'mysql', 'Natural Language Processing', 'nested_dir', 'New folder', 'OpenAI', 'os-demo-2', 'pgAdmin 4.lnk', 'Porfo
# ...

# %%
os.chdir('nested_dir/')

# %%
os.listdir()
# Out:
# ['inner_dir']

# %%
os.chdir("c:/Users/vamsh/OneDrive/Desktop/")
os.listdir()
# Out:
# ['.git',
#  '.hgf.txt',
#  'APPLICATION SYSTEM TRACKING',
#  'ATS',
#  'Audio',
#  'ayncio1',
#  'Blitz.lnk',
#  'books to read',
#  'cataract detection',
#  'Cataract-Detection-and-Classification',
#  'certificates',
#  'cfx_dashboard',
#  'Data',
#  'Datascience-projects',
#  'Deepgram',
#  'desktop.ini',
#  'Discord.lnk',
#  'Django',
#  'django and postgre',
#  'django blog app',
#  'django blog project',
#  'django channels',
#  'django models',
#  'django rest framework',
#  'django-api-error-handling',
#  'django-celery',
#  'django-concepts',
#  'django-project',
#  'django-user-model',
#  'Django2',
#  'Docker Desktop.lnk',
#  'DSA PYTHON',
#  'fav chikk',
#  'FILE.sql',
#  'final project',
#  'final project.zip',
#  'Flask project 1',
#  'for testing',
#  'Front-End',
#  'HTML',
#  'kaggle projects',
#  'MACHINE LEARNING',
#  'Microsoft Teams classic (work or school).lnk',
#  'mid term Project presentaion.pptx',
#  'ML project',
#  'mongodb',
#  'MongoDBCompass.lnk',
# ...

# %%
#TO delete directories

#os.rmdir('os-demo-2')
#os.rmdir('nested_dir/inner_dir/')
os.rmdir('nested_dir')

# %%
#rename directories

os.rename('weight_tracking.xlsx', 'wight.xlsx')
print(os.listdir())
# Out:
# ['.git', '.hgf.txt', 'APPLICATION SYSTEM TRACKING', 'ATS', 'Audio', 'ayncio1', 'Blitz.lnk', 'books to read', 'cataract detection', 'Cataract-Detection-and-Classification', 'certificates', 'cfx_dashboard', 'Data', 'Datascience-projects', 'Deepgram', 'desktop.ini', 'Discord.lnk', 'Django', 'django and postgre', 'django blog app', 'django blog project', 'django channels', 'django models', 'django rest framework', 'django-api-error-handling', 'django-celery', 'django-concepts', 'django-project', 'django-user-model', 'Django2', 'Docker Desktop.lnk', 'DSA PYTHON', 'fav chikk', 'FILE.sql', 'final project', 'final project.zip', 'Flask project 1', 'for testing', 'Front-End', 'HTML', 'kaggle projects', 'MACHINE LEARNING', 'Microsoft Teams classic (work or school).lnk', 'mid term Project presentaion.pptx', 'ML project', 'mongodb', 'MongoDBCompass.lnk', 'Movie Recomendation System', 'mysql', 'Natural Language Processing', 'New folder', 'OpenAI', 'pgAdmin 4.lnk', 'Porfolio-HTML', 'portfolio-HTML&
# ...

# %%
print(os.stat('wight.xlsx'))  #size, modification time,
# Out:
# os.stat_result(st_mode=33206, st_ino=18858823439716099, st_dev=8793999955972856169, st_nlink=1, st_uid=0, st_gid=0, st_size=14601, st_atime=1732945127, st_mtime=1732945124, st_ctime=1732339735)

# %%
from datetime import datetime

mod_time = os.stat('wight.xlsx').st_mtime
print(datetime.fromtimestamp(mod_time))
# Out:
# 2024-11-30 11:08:44.283657

# %%
for dirpath, dirnames, filenames in os.walk("c:/Users/vamsh/OneDrive/Desktop/"):
    print('Current path', dirpath)
    print('Directories', dirnames)
    print('Files', filenames)

# %%
#get environment variables


os.environ
# Out:
# environ{'ACSVCPORT': '17532',
#         'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\vamsh\\AppData\\Roaming',
#         'APPLICATIONINSIGHTS_CONFIGURATION_CONTENT': '{}',
#         'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1',
#         'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey',
#         'CHOCOLATEYLASTPATHUPDATE': '133747394047299476',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_3344_LOLLNBYQKFTZZFVN',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'ASUS',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'CUDA_PATH': 'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v12.5',
#         'CUDA_PATH_V12_5': 'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v12.5',
# ...

# %%
print(os.environ.get("EMAIL_USER"))
# Out:
# vamshisaideep@gmail.com

# %%
#os.path.join('  ', '  ') ---> joining file paths

# %%
print(os.path.basename("APPLICATION SYSTEM TRACKING/accounts/app.py"))
# Out:
# app.py

# %%
print(os.path.split('/tmp/test.txt'))
# Out:
# ('/tmp', 'test.txt')

# %%
print(os.path.exists('/tmp/test.txt')) #to check if dir exists or not
# Out:
# False

# %%
print(os.path.splitext('/tmp/test.txt'))
# Out:
# ('/tmp/test', '.txt')

# %%
print(dir(os.path))
# Out:
# ['_LCMAP_LOWERCASE', '_LCMapStringEx', '_LOCALE_NAME_INVARIANT', '__all__', '__builtins__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_abspath_fallback', '_get_bothseps', '_getfinalpathname', '_getfinalpathname_nonstrict', '_getfullpathname', '_getvolumepathname', '_nt_readlink', '_path_isdevdrive', '_readlink_deep', 'abspath', 'altsep', 'basename', 'commonpath', 'commonprefix', 'curdir', 'defpath', 'devnull', 'dirname', 'exists', 'expanduser', 'expandvars', 'extsep', 'genericpath', 'getatime', 'getctime', 'getmtime', 'getsize', 'isabs', 'isdevdrive', 'isdir', 'isfile', 'isjunction', 'islink', 'ismount', 'join', 'lexists', 'normcase', 'normpath', 'os', 'pardir', 'pathsep', 'realpath', 'relpath', 'samefile', 'sameopenfile', 'samestat', 'sep', 'split', 'splitdrive', 'splitext', 'splitroot', 'stat', 'supports_unicode_filenames', 'sys']
